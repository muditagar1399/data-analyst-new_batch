# %% [markdown]
# # BASIC PROGRAMMING

# %%
## we are starting basic programming

# %%
# print function

# %%
print("my name is mudit : ")
# Out:
# my name is mudit :

# %%
# add two numbers :

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
# unlike sql we dont write data type here for ex we simply assign the value to the variables instead of declaring them

# %%
#checking the dataype

# %%
type(a)
# Out:
# int

# %%
# to check data type we can do type function

# %%
# taking user input to add two numbers

# %%
a=int(input("enter the number : "))
b=int(input(" enter second number : "))
c=a+b
print(c)
# Out:
# enter the number :  45
#  enter second number :  45
# 90

# %%
# to find even and odd number

# %%
a=int(input("enter a number : "))
if a%2==0:
    print("the number is even")
else:
    print("the number is odd")
# Out:
# enter a number :  10
# the number is even

# %%
# to find is the number is +ve , -ve or 0

# %%
a=int(input("enter a number  :"))
if a>0:
    print("positive number :")
elif a<0:
    print("negative number : ")
else:
    print("zero")
# Out:
# enter a number  45
# positive number :

# %%
# 3 programs 
#subtract two number 
# divide two numbers 
#mutliply two numbers 
# do all this using input function 
# practice this programs
